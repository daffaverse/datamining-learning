# %%
from sklearn.datasets import load_iris
import pandas as pd

# Load dataset Iris
iris = load_iris()

# Konversi ke DataFrame
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df["target"] = iris.target

# Simpan ke file CSV
df.to_csv("iris_dataset.csv", index=False)

print("Dataset Iris berhasil disimpan sebagai iris_dataset.csv")
# Out:
# Dataset Iris berhasil disimpan sebagai iris_dataset.csv
